# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the dataset

# %%
data = pd.read_csv("airquality.csv", index_col = 0)

# %% [markdown]
# ---
#
# # Investigate the structure of the dataset
#
# 1. Ozone : mean levels at Roosevelt Island
# 2. Solar.R : solar radiation at Central Park
# 3. Wind : avg wind speed at LaGuaridia Airport
# 4. Temp : max daily temp at LaGuaridia Airport
#
# ## Questions
# 1. How is the data collected as in what sensors are in use?
# 2. Why track these vars/cols?
# 3. Of the plot (view), what labels to provide the x & y axis, respectively?

# %%
oz = data['Ozone']
so_R = data['Solar.R']
wind = data['Wind']
temp = data['Temp']
month = data['Month']
day = data['Day']

# %% [markdown]
# ## Table View

# %%
print("data : \n", data)
# Out:
# data :
#       Ozone  Solar.R  Wind  Temp  Month  Day
# 1     41.0    190.0   7.4    67      5    1
# 2     36.0    118.0   8.0    72      5    2
# 3     12.0    149.0  12.6    74      5    3
# 4     18.0    313.0  11.5    62      5    4
# 5      NaN      NaN  14.3    56      5    5
# ..     ...      ...   ...   ...    ...  ...
# 149   30.0    193.0   6.9    70      9   26
# 150    NaN    145.0  13.2    77      9   27
# 151   14.0    191.0  14.3    75      9   28
# 152   18.0    131.0   8.0    76      9   29
# 153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 6 columns]

# %% [markdown]
# ## Plot View

# %%
data.plot()

# %% [markdown]
# ---
#
# # Plot each of the four series
#
# ## Questions
# 1. What's the best graph/plot to use & why?
# 2. Would my plots look differently if I removed/replaced/interpolated the NaN values?

# %% [markdown]
# ## 1. Ozone
#
# 1. density plot : if I randomly sample from this distribution,
#     - bw_method : used to calc the **est bandwidth**; if low $ \rightarrow $ overfitting & if high $ \rightarrow $ underfitting
#
# 2. scatter plot : shows the frequency at which each mean occurs

# %%
plot_oz_den = oz.plot.kde(bw_method = 0.3)
print("plot_oz_den : \n", plot_oz_den)
# Out:
# plot_oz_den :
#  AxesSubplot(0.125,0.125;0.775x0.755)

# %%
plot_oz_sca = oz.plot.hist()
print("plot_oz_sca : \n", plot_oz_sca)
# Out:
# plot_oz_sca :
#  AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ## Solar Radiation

# %% [markdown]
# ## Wind

# %% [markdown]
# ## Temperature
