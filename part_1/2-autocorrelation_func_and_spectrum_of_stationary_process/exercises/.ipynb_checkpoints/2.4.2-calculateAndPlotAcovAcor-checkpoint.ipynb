# %% [markdown]
# # Implementation 2 of Estimating the ACov and ACor
#
# - See the problem statement with notes at [2.4-mainWithGoalAndNotes.ipynb](https://github.com/Brinkley97/book-forecasting_and_control/blob/main/part_1/2-autocorrelation_func_and_spectrum_of_stationary_process/exercises/2.4-mainWithGoalAndNotes.ipynb)
#
# - See implementation 1 at [2.4.1-withDarian.ipynb](https://github.com/Brinkley97/book-forecasting_and_control/blob/main/part_1/2-autocorrelation_func_and_spectrum_of_stationary_process/exercises/2.4.1-withDarian.ipynb)

# %% [markdown]
# # TODOs
#
# - [x] Imports + Load Data
#
# - [x] (2.1.12) **Estimate the ACov @ lag k :** $ \hat{\gamma}_{k} $ (gamma hat) = 1/N * $ \sum_{t=1}^{N - k} (z_{t} - \bar{z})(z_{t+k} - \bar{z}) $ k = 0, 1, 2,..., K
#
# - [x] (2.1.12) Set : $ c_k $ = $ \hat{\gamma}_{k} $
#
# - [x] (2.1.11) **Estimate the ACor @ lag k :** $ \hat{\rho}{_k} $ (rho hat) = $ c_k $ / $ c_0 $
#
# - [x] (2.1.11) Set : $ r_k $ to  $ \hat{\rho}{_k} $
#
# - [x] Verify with [LEW dataset](https://www.itl.nist.gov/div898/handbook/eda/section3/eda35c.htm)
#
# - [x] Graph $ r_k $

# %% [markdown]
# ## Imports + Load Data

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
BASE = '/Users/brinkley97/Documents/development/'
path_to_datasets = 'book-forecasting_and_control_by_4_Gs/datasets/'

# %%
# lew
lew_dataset_file = "lewDataset.csv"
lew_dataset = BASE + path_to_datasets + lew_dataset_file

# %%
irvine_blood_sugar_dataset = "irvinePrePostMeals.csv"
irvine_pre_post_meals = BASE + path_to_datasets + irvine_blood_sugar_dataset

# %%
book_dataset = [200, 202, 208, 204, 204, 207, 207, 204, 202, 199, 201, 198, 200, 
        202, 203, 205, 207, 211, 204, 206, 203, 203, 201, 198, 200, 206, 
        207, 206, 200, 203, 203, 200, 200, 195, 202, 204, 207, 206, 200]

# %%
def basic_stats(path_to_data):
    """
    
    Parameter:
    path_to_data -- py list or pd DF (of the data)
    
    Return
    z, N, lags_range, mean_of_data -- py tuple (of the data, lenght of data, range of lag values, mean of the data)
    """
    
    print(type(path_to_data))
    
    type_is_list = isinstance(path_to_data, list)
    
    if type_is_list == False:
        data = pd.read_csv(path_to_data)
        if len(data.columns) == 1: 
            z = data.iloc[0:, 0]
        elif len(data.columns) == 2: 
            z = data.iloc[0:, 1]
        else:
            print("Check #columns")
            print(data)
    else:
        z = path_to_data
        
    N = len(z)
    lags_range = range(0, N)
    mean_of_data = np.mean(z)
    
    return z, N, lags_range, mean_of_data

# %%
z, N, ks, zbar = basic_stats(lew_dataset)
# z, N, ks, zbar = basic_stats(irvine_pre_post_meals)
# z, N, ks, zbar = basic_stats(book_dataset)
# Out:
# <class 'str'>

# %%
z
# N
# ks
# zbar
# Out:
# 0     -213
# 1     -564
# 2      -35
# 3      -15
# 4      141
#       ...
# 195   -385
# 196    198
# 197   -218
# 198   -536
# 199     96
# Name: measurements, Length: 200, dtype: int64

# %% [markdown]
# ## Estimate AutoCov @ lag k

# %%
def est_autocov(data, len_of_data, lag_ks, sample_mean): 
    """Calculate the estimated autocovariance
    
    Parameters:
    data -- py int (of numerical values in data)
    len_of_data -- py int (of the data length)
    lag_ks -- py list (of k values)
    sample_mean -- py float (of the mean of the data)
    
    Return:
    a list of tuples (ck idex, ck float value)
    
    """
    
    store_c_ks = []
    
    for k in range(len(lag_ks)):
        # print("k:", k)
        gamma_k = 0
        
        for t in range(len_of_data - k):
            # print("t:", t)
            # when we have a new index of lag_k, hence 0, 1, ..., K
            diff_between_zt_and_sample_mean = (data[t] - sample_mean)
            # print(t_sm)
            diff_between_ztk_and_sample_mean = data[t + k] - sample_mean
            # print(tk_sm)
            gamma_k += diff_between_zt_and_sample_mean * diff_between_ztk_and_sample_mean
            # print(gamma_k)
            # print()

            # print("gamma_k : ", gamma_k)
        # print("k: ", k, "@Last gamma_k:", gamma_k)

        c_ks = k, gamma_k/N
        store_c_ks.append(c_ks)
    return store_c_ks

# %%
c_ks = est_autocov(z, N, ks, zbar)
c_ks
# Out:
# [(0, 76528.56577500004),
#  (1, -23517.595646125),
#  (2, -56657.944042250005),
#  (3, 59285.855336625),
#  (4, 15700.251415500008),
#  (5, -68734.59878062503),
#  (6, 28779.622398249987),
#  (7, 48430.83590212498),
#  (8, -58870.063744),
#  (9, -9556.184915124997),
#  (10, 63098.80773875),
#  (11, -30644.598357374998),
#  (12, -41808.83645349999),
#  (13, 55982.608025375),
#  (14, 5462.814454249996),
#  (15, -57880.60436687498),
#  (16, 30771.480036999994),
#  (17, 36876.433015874994),
#  (18, -53237.202280250014),
#  (19, -2545.668876374998),
#  (20, 53609.00165249999),
#  (21, -31363.055518625006),
#  (22, -32881.37568975001),
#  (23, 51287.719164124996),
#  (24, -48.40695700000298),
#  (25, -50381.45885312501),
#  (26, 31790.64832575),
#  (27, 29733.49325462501),
#  (28, -50070.91021650001),
#  (29, 2004.9606623749976),
#  (30, 48143.22476624997),
#  (31, -32262.69242987499),
#  (32, -27316.240651000004),
#  (33, 49026.011477875),
#  (34, -4012.3941932500006),
#  (35, -45995.155439375005),
#  (36, 33150.225189499964),
#  (37, 24618.676343375),
#  (38, -48694.15205275001),
#  (39, 6429.1827011250025),
#  (40, 44113.56813),
#  (41, -34401.804866124985),
#  (42, -21650.75691225),
#  (43, 47227.019616624995),
#  (44, -8023.863979499998),
#  (45, -41721.06960062501),
#  (46, 34711.10132825001),
#  (47, 19164.135007124998),
#  (48, -46521.27423899998),
#  (49, 10708.647564874998),
#  (50, 38823.00739374999),
#  (51, -35019.471852375005),
#  (52, -15886.998548499996),
#  (53, 44274.96173037501),
#  (54, -12385.432140750005),
#  (55, -35619.71493687501),
#  (56, 34521.448917),
#  (57, 13115.945520874993),
#  (58, -42095.02262525001),
#  (59, 13636.872753625),
#  (60, 32847.87903250001),
#  (61, -34123.380663624994),
#  (62, -11062.13540975),
#  (63, 40618.181769124996),
#  (64, -14713.411701999994),
#  (65, -31011.849448124998),
#  (66, 34194.96558074999),
#  (67, 9334.988859625002),
#  (68, -39829.23523650001),
#  (69, 15470.899117375002),
#  (70, 29693.50597124999),
#  (71, -33524.349099874984),
#  (72, -8228.414645999997),
#  (73, 38133.24998287501),
#  (74, -15935.445413250003),
#  (75, -27672.666259374986),
#  (76, 33168.3496945),
#  (77, 6184.998173374999),
#  (78, -36607.51542275),
#  (79, 17114.220581125013),
#  (80, 25091.439109999992),
#  (81, -32710.045736125),
#  (82, -3928.2491072499984),
#  (83, 34428.997446625006),
#  (84, -17738.64327450001),
#  (85, -22051.853495624993),
#  (86, 30775.576258249996),
#  (87, 1906.8595621249976),
#  (88, -30884.25998399999),
#  (89, 17383.176169875005),
#  (90, 19331.691173750005),
#  (91, -29202.25284737501),
#  (92, -821.7602934999991),
#  (93, 29179.279860375005),
#  (94, -17586.971735750005),
#  (95, -17742.770731875),
#  (96, 28720.259521999997),
#  (97, -736.1591991249979),
#  (98, -27959.695445250018),
#  (99, 18509.114758624994),
#  (100, 15666.7703875),
#  (101, -28266.608983625003),
#  (102, 2535.426220249997),
#  (103, 26231.469974125),
#  (104, -19094.27874699999),
#  (105, -13657.023493124996),
#  (106, 27209.91751075),
#  (107, -3840.114085375002),
#  (108, -24157.9389315),
#  (109, 18933.368622375),
#  (110, 11898.264601249994),
#  (111, -26271.870394875),
#  (112, 4819.035758999997),
#  (113, 22827.201212875),
#  (114, -19281.265483250005),
#  (115, -9954.915729374998),
#  (116, 25038.214049500013),
#  (117, -6457.796671625003),
#  (118, -20129.660117749998),
#  (119, 19287.566511124995),
#  (120, 7084.781665),
#  (121, -23179.289806125005),
#  (122, 8003.961197750003),
#  (123, 16818.572601624997),
#  (124, -18363.3639195),
#  (125, -4181.927965624999),
#  (126, 19749.65618825),
#  (127, -8551.144207875004),
#  (128, -12986.704579000001),
#  (129, 16349.979874874996),
#  (130, 1804.2148037499978),
#  (131, -16555.028342375),
#  (132, 8659.136011499997),
#  (133, 9933.491915375002),
#  (134, -14495.814805750002),
#  (135, -454.4147768750015),
#  (136, 14024.362476999999),
#  (137, -8279.215994124997),
#  (138, -8326.703815250003),
#  (139, 12947.186438625002),
#  (140, -86.36325750000022),
#  (141, -12436.846978624993),
#  (142, 7865.05840025),
#  (143, 7183.000254125001),
#  (144, -12115.208142000001),
#  (145, 764.6957118749986),
#  (146, 11153.487915750002),
#  (147, -7969.440955374997),
#  (148, -5640.7906765000025),
#  (149, 11552.632627375),
#  (150, -2262.81161875),
#  (151, -10039.141789875),
#  (152, 8728.650014000003),
#  (153, 4948.600767874999),
#  (154, -9790.13055325),
#  (155, 3271.0053756249986),
#  (156, 6932.924754500002),
#  (157, -8170.053841624999),
#  (158, -2538.237312749999),
#  (159, 9539.500641125),
#  (160, -3955.782354999999),
#  (161, -6657.281926125001),
#  (162, 8319.622827749998),
#  (163, 819.7594316250003),
#  (164, -8483.7794145),
#  (165, 4821.166214374999),
#  (166, 4739.69496825),
#  (167, -7718.245702875),
#  (168, 825.5214259999995),
#  (169, 6637.913204875),
#  (170, -5443.603991250001),
#  (171, -2519.309887375),
#  (172, 6888.1709915),
#  (173, -2372.402479625),
#  (174, -4773.5025507499995),
#  (175, 5511.234628125001),
#  (176, 558.5977320000002),
#  (177, -5506.4233891250005),
#  (178, 3313.7264647500006),
#  (179, 2554.506293625),
#  (180, -4822.650877499999),
#  (181, 1186.5446513749996),
#  (182, 3378.2180552500004),
#  (183, -3468.287240875),
#  (184, -342.0892620000001),
#  (185, 3110.875141875),
#  (186, -1974.62867925),
#  (187, -1090.1422503750002),
#  (188, 2261.4822285),
#  (189, -822.960867625),
#  (190, -1065.35196375),
#  (191, 1254.240690125),
#  (192, -293.61548099999993),
#  (193, -348.9751271249999),
#  (194, 508.37337675),
#  (195, -573.4904443749999),
#  (196, -21.640640500000007),
#  (197, 894.990438375),
#  (198, -464.74018275000003),
#  (199, -48.62357887499999)]

# %% [markdown]
# ## Estimate AutoCor @ lag k

# %%
def est_autocor(data, N, lag_k, sample_mean, c_ks):
    """Calculate the estimated autocorrelation
    
    Parameters:
    data -- py int (of numerical values in data)
    len_of_data -- py int (of the data length)
    lag_k -- py list (of k values)
    sample_mean -- py float (of the mean of the data)
    c_ks -- py list (of tuple values)
    
    
    Return:
    a tuple (of kth lag, value at kth lag) in a list
    
    """

    store_r_ks = []
    
    for k in range(len(lag_k)):
        c_k_index, c_k_value = c_ks[k]
        # print("\nc_k : ", c_k_value)

        c_k_index, cnot = c_ks[0]
        # print("cnot : ", cnot)

        rho_hat_k = np.divide(c_k_value, cnot)
        # print("rho_hat_k : ", rho_hat_k)
        
        r_ks = k, np.round(rho_hat_k, 5)
        store_r_ks.append(r_ks)
    
    return store_r_ks

# %%
r_ks = est_autocor(z, N, ks, zbar, c_ks)
r_ks
# Out:
# [(0, 1.0),
#  (1, -0.31),
#  (2, -0.74),
#  (3, 0.77),
#  (4, 0.21),
#  (5, -0.9),
#  (6, 0.38),
#  (7, 0.63),
#  (8, -0.77),
#  (9, -0.12),
#  (10, 0.82),
#  (11, -0.4),
#  (12, -0.55),
#  (13, 0.73),
#  (14, 0.07),
#  (15, -0.76),
#  (16, 0.4),
#  (17, 0.48),
#  (18, -0.7),
#  (19, -0.03),
#  (20, 0.7),
#  (21, -0.41),
#  (22, -0.43),
#  (23, 0.67),
#  (24, -0.0),
#  (25, -0.66),
#  (26, 0.42),
#  (27, 0.39),
#  (28, -0.65),
#  (29, 0.03),
#  (30, 0.63),
#  (31, -0.42),
#  (32, -0.36),
#  (33, 0.64),
#  (34, -0.05),
#  (35, -0.6),
#  (36, 0.43),
#  (37, 0.32),
#  (38, -0.64),
#  (39, 0.08),
#  (40, 0.58),
#  (41, -0.45),
#  (42, -0.28),
#  (43, 0.62),
#  (44, -0.1),
#  (45, -0.55),
#  (46, 0.45),
#  (47, 0.25),
#  (48, -0.61),
#  (49, 0.14),
#  (50, 0.51),
#  (51, -0.46),
#  (52, -0.21),
#  (53, 0.58),
#  (54, -0.16),
#  (55, -0.47),
#  (56, 0.45),
#  (57, 0.17),
#  (58, -0.55),
#  (59, 0.18),
#  (60, 0.43),
#  (61, -0.45),
#  (62, -0.14),
#  (63, 0.53),
#  (64, -0.19),
#  (65, -0.41),
#  (66, 0.45),
#  (67, 0.12),
#  (68, -0.52),
#  (69, 0.2),
#  (70, 0.39),
#  (71, -0.44),
#  (72, -0.11),
#  (73, 0.5),
#  (74, -0.21),
#  (75, -0.36),
#  (76, 0.43),
#  (77, 0.08),
#  (78, -0.48),
#  (79, 0.22),
#  (80, 0.33),
#  (81, -0.43),
#  (82, -0.05),
#  (83, 0.45),
#  (84, -0.23),
#  (85, -0.29),
#  (86, 0.4),
#  (87, 0.02),
#  (88, -0.4),
#  (89, 0.23),
#  (90, 0.25),
#  (91, -0.38),
#  (92, -0.01),
#  (93, 0.38),
#  (94, -0.23),
#  (95, -0.23),
#  (96, 0.38),
#  (97, -0.01),
#  (98, -0.37),
#  (99, 0.24),
#  (100, 0.2),
#  (101, -0.37),
#  (102, 0.03),
#  (103, 0.34),
#  (104, -0.25),
#  (105, -0.18),
#  (106, 0.36),
#  (107, -0.05),
#  (108, -0.32),
#  (109, 0.25),
#  (110, 0.16),
#  (111, -0.34),
#  (112, 0.06),
#  (113, 0.3),
#  (114, -0.25),
#  (115, -0.13),
#  (116, 0.33),
#  (117, -0.08),
#  (118, -0.26),
#  (119, 0.25),
#  (120, 0.09),
#  (121, -0.3),
#  (122, 0.1),
#  (123, 0.22),
#  (124, -0.24),
#  (125, -0.05),
#  (126, 0.26),
#  (127, -0.11),
#  (128, -0.17),
#  (129, 0.21),
#  (130, 0.02),
#  (131, -0.22),
#  (132, 0.11),
#  (133, 0.13),
#  (134, -0.19),
#  (135, -0.01),
#  (136, 0.18),
#  (137, -0.11),
#  (138, -0.11),
#  (139, 0.17),
#  (140, -0.0),
#  (141, -0.16),
#  (142, 0.1),
#  (143, 0.09),
#  (144, -0.16),
#  (145, 0.01),
#  (146, 0.15),
#  (147, -0.1),
#  (148, -0.07),
#  (149, 0.15),
#  (150, -0.03),
#  (151, -0.13),
#  (152, 0.11),
#  (153, 0.06),
#  (154, -0.13),
#  (155, 0.04),
#  (156, 0.09),
#  (157, -0.11),
#  (158, -0.03),
#  (159, 0.12),
#  (160, -0.05),
#  (161, -0.09),
#  (162, 0.11),
#  (163, 0.01),
#  (164, -0.11),
#  (165, 0.06),
#  (166, 0.06),
#  (167, -0.1),
#  (168, 0.01),
#  (169, 0.09),
#  (170, -0.07),
#  (171, -0.03),
#  (172, 0.09),
#  (173, -0.03),
#  (174, -0.06),
#  (175, 0.07),
#  (176, 0.01),
#  (177, -0.07),
#  (178, 0.04),
#  (179, 0.03),
#  (180, -0.06),
#  (181, 0.02),
#  (182, 0.04),
#  (183, -0.05),
#  (184, -0.0),
#  (185, 0.04),
#  (186, -0.03),
#  (187, -0.01),
#  (188, 0.03),
#  (189, -0.01),
#  (190, -0.01),
#  (191, 0.02),
#  (192, -0.0),
#  (193, -0.0),
#  (194, 0.01),
#  (195, -0.01),
#  (196, -0.0),
#  (197, 0.01),
#  (198, -0.01),
#  (199, -0.0)]

# %% [markdown]
# # Graph AutoCor

# %%
def line_plot(x, y):
    fig, ax = plt.subplots()
    ax.plot(x, y, linewidth=3.0)

# %%
def autocor_plot(x, y, max_lags):
    fig, [ax1, ax2] = plt.subplots(2, 1)
    ax1.xcorr(x, y, maxlags=ks[max_lags], usevlines = True, normed = True, lw=2)
    ax1.grid(True)

    # ks x-axis; pho_k = -pho_k
    ax2.acorr(y, maxlags=ks[max_lags], usevlines = True, normed = True, lw=2)
    ax2.grid(True)
    
    # plt.title("Autocorrelation")
    plt.xlabel('k Lags')
    
    plt.ylabel('Autocorrelation')
    
    plt.xlim([0, max_lags])

# %%
def graph_est_autocor(x, y, r_ks, len_rks):
    
    max_lags = 10
    
    for idx in range(len_rks):
        x.append(r_ks[idx][0])
        # print("x : ", x)
        y.append(r_ks[idx][1])
        # print("y : ", y, "\n")    
    
    return line_plot(x, y), autocor_plot(x, y, max_lags)

# %%
lags = []
autocor = []
len_rks = len(r_ks)
# graph_est_autocor(lags, autocor, r_ks, len_rks)
